# %%
# !pip install diffusers transformers ftfy accelerate

# %%
import torch
import requests
from PIL import Image
from io import BytesIO
from diffusers import StableDiffusionImg2ImgPipeline

device = 'cuda'

pipe = StableDiffusionImg2ImgPipeline.from_pretrained('nitrosocke/Ghibli-Diffusion', torch_dtype=torch.float16).to(device)

# %%
url = 'https://raw.githubusercontent.com/CompVis/stable-diffusion/main/assets/stable-samples/img2img/sketch-mountains-input.jpg'

response = requests.get(url)
init_image = Image.open(BytesIO(response.content)).convert("RGB")
init_image.thumbnail((768, 768))
init_image

# %%
prompt = "ghibli style, a fantasy landscape with castles"
generator = torch.Generator(device=device).manual_seed(1024)
image = pipe(prompt=prompt, image=init_image, strength=0.75, guidence_scale=7.5, generator=generator).images[0]
image
